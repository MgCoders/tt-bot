# %%
from Repository import Repository
repo = Repository('rutinas','gymbot','mongodb://mongo:27017/gymbot')

# %%
rutina = {
      "nombre": "rutina1",
      "profesor": "seba",
      "descripcion": "lala lala",
      "dia": [
        {
          "nombre":"dia 1",
          "ejercicio":[
            {
              "nombre":"Press en Banco",
              "peso_max":-1,
              "serie":[
                {
                  "numero":1,
                  "repeticiones":5,
                  "porcentaje_peso_max":65,
                  "carga":-1
                },
                {
                  "numero":2,
                  "repeticiones":5,
                  "porcentaje_peso_max":75,
                  "carga":-1
                },
                {
                  "numero":3,
                  "repeticiones":5,
                  "porcentaje_peso_max":85,
                  "carga":-1
                }
                ]
            },
            {
              "nombre":"Apertura con Mancuerna",
              "carga":-1,
              "serie":[
                {
                  "numero":1,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":2,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":3,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":15,
                  "carga":-1
                }
                ]
            },
            {
              "nombre":"Remo con Mancuerna",
              "carga":-1,
              "serie":[
                {
                  "numero":1,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":2,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":3,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":10,
                  "carga":-1
                }
                ]
            }
            ]
        }
      ]
    }
{
      "nombre": "rutina1",
      "profesor": "seba",
      "descripcion": "lala lala",
      "dia": [
        {
          "nombre":"dia 1",
          "ejercicio":[
            {
              "nombre":"Press en Banco",
              "peso_max":-1,
              "serie":[
                {
                  "numero":1,
                  "repeticiones":5,
                  "porcentaje_peso_max":65,
                  "carga":-1
                },
                {
                  "numero":2,
                  "repeticiones":5,
                  "porcentaje_peso_max":75,
                  "carga":-1
                },
                {
                  "numero":3,
                  "repeticiones":5,
                  "porcentaje_peso_max":85,
                  "carga":-1
                }
                ]
            },
            {
              "nombre":"Apertura con Mancuerna",
              "carga":-1,
              "serie":[
                {
                  "numero":1,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":2,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":3,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":15,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":15,
                  "carga":-1
                }
                ]
            },
            {
              "nombre":"Remo con Mancuerna",
              "carga":-1,
              "serie":[
                {
                  "numero":1,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":2,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":3,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":10,
                  "carga":-1
                },
                {
                  "numero":5,
                  "repeticiones":10,
                  "carga":-1
                }
                ]
            }
            ]
        }
      ]
    }.save(rutina)
# Out:
# /opt/ds/lib/python2.7/site-packages/ipykernel/__main__.py:99: DeprecationWarning: save is deprecated. Use insert_one or replace_one instead
# ObjectId('58dcfcaeffccfe001090564c')

# %%
from pprint import pprint
print pprint(list(repo.getDataCollection().find())[0])
# Out:
# {u'_id': ObjectId('58dcfcaeffccfe001090564c'),
#  u'descripcion': u'lala lala',
#  u'dia': [{u'ejercicio': [{u'nombre': u'Press en Banco',
#                            u'peso_max': -1,
#                            u'serie': [{u'carga': -1,
#                                        u'numero': 1,
#                                        u'porcentaje_peso_max': 65,
#                                        u'repeticiones': 5},
#                                       {u'carga': -1,
#                                        u'numero': 2,
#                                        u'porcentaje_peso_max': 75,
#                                        u'repeticiones': 5},
#                                       {u'carga': -1,
#                                        u'numero': 3,
#                                        u'porcentaje_peso_max': 85,
#                                        u'repeticiones': 5}]},
#                           {u'carga': -1,
#                            u'nombre': u'Apertura con Mancuerna',
#                            u'serie': [{u'carga': -1,
#                                        u'numero': 1,
#                                        u'repeticiones': 15},
#                                       {u'carga': -1,
#                                        u'numero': 2,
#                                        u'repeticiones': 15},
#                                       {u'carga': -1,
#                                        u'numero': 3,
#                                        u'repeticiones': 15},
#                                       {u'carga': -1,
#                                        u'numero': 5,
#                                        u'repeticiones': 15},
#                                       {u'carga': -1,
#                                        u'numero': 5,
#                                        u'repeticiones': 15}]},
#                           {u'carga': -1,
#                            u'nombre': u'Remo con Mancuerna',
#                            u'serie': [{u'carga': -1,
#                                        u'numero': 1,
#                                        u'repeticiones': 10},
#                                       {u'carga': -1,
#                                        u'numero': 2,
#                                        u'repeticiones': 10},
#                                       {u'carga': -1,
#                                        u'numero': 3,
#                                        u'repeticiones': 10},
#                                       {u'carga': -1,
#                                        u'numero': 5,
#                                        u'repeticiones': 10},
#                                       {u'carga': -1,
#                                        u'numero': 5,
#                                        u'repeticiones': 10}]}],
#            u'nombre': u'dia 1'}],
#  u'nombre': u'rutina1',
#  u'profesor': u'seba'}
# None

# %%
from Repository import Repository
users = Repository('usuarios','gymbot','mongodb://mongo:27017/gymbot')

# %%
users.getDataCollection().insert_one({"nombre":"raul","numero":"+59899725258"})
